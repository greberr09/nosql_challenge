# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
import pandas as pd

from bson import ObjectId
from pprint import pprint

import os

import sys
sys.path.append("../")

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in the uk_food database
collection_names = db.list_collection_names()
collection_names
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# review a document in the establishments collection to get fields and structure

# Capture the results to a variable

document = db.establishments.find_one()

# Pretty print the document

pprint(document)
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64964158613d83e2052dc543'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# Find the establishments with a hygiene score of 20

# setup the query
query = {'scores.Hygiene':  20}

# Retrieve the documents 
hygiene_docs = establishments.find(query)

# Use count_documents to get the number of documents
num_scores = establishments.count_documents(query)

# print the count                     
print(f"there are: {num_scores} hygiene scores equal to 20.")
              
# Display the first document in the results using pprint
hygiene_docs = establishments.find(query)

first_hygiene_doc = hygiene_docs[0]
 
print("One instance:")    
pprint(first_hygiene_doc)
# Out:
# there are: 41 hygiene scores equal to 20.
# One instance:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64964158613d83e2052de075'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame

hygiene_df = pd.DataFrame(hygiene_docs)

# Display the number of rows in the DataFrame

print(f"There are {len(hygiene_df)} entries in the hygiene data frame.")

# Display the first 10 rows of the DataFrame
      
hygiene_df.head(10)
# Out:
# There are 41 entries in the hygiene data frame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  64964158613d83e2052de075   110681                  0
# 1  64964158613d83e2052de3f5   612039                  0
# 2  64964158613d83e2052de700   730933                  0
# 3  64964158613d83e2052de8ef   172735                  0
# 4  64964158613d83e2052de8ff   172953                  0
# 5  64964158613d83e2052df2a1   512854                  0
# 6  64964158613d83e2052df4be  1537089                  0
# 7  64964159613d83e2052e09e7   155648                  0
# 8  64964159613d83e2052e0e2c  1012883                  0
# 9  64964159613d83e2052e163f   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and having a RatingValue greater than or equal to 4.

query = {'LocalAuthorityName': {'$regex': 'London'}, 'RatingValue': {'$gte': 4}}
                                                                                                 
london_ratings_docs = establishments.find(query)
                                                          
# Use count_documents to get the number of documents
num_docs = establishments.count_documents(query)

# print the count                     
print(f"there are: {num_docs} London entities with ratings values of 4 or higher.")
              
# Display the first document in the results using pprint

print("One instance:")    
pprint(london_ratings_docs[0])
# Out:
# there are: 33 London entities with ratings values of 4 or higher.
# One instance:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64964158613d83e2052dfa92'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame

london_df = pd.DataFrame(london_ratings_docs)

# Display the number of rows in the DataFrame

print(f"There are {len(london_df)} entries in the London ratings data frame.")

# Display the first 10 rows of the DataFrame
      
london_df.head(10)
# Out:
# There are 33 entries in the London ratings data frame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  64964158613d83e2052dfa92   621707                  0
# 1  64964158613d83e2052dfdb9  1130836                  0
# 2  64964159613d83e2052e0904   293783                  0
# 3  64964159613d83e2052e1702  1315095                  0
# 4  64964159613d83e2052e1703   294474                  0
# 5  64964159613d83e2052e1e0e   294900                  0
# 6  64964159613d83e2052e3f1b   293756                  0
# 7  64964159613d83e2052e42df   878523                  0
# 8  64964159613d83e2052e42fc   294606                  0
# 9  64964159613d83e2052e42fd   295107                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000016185                              WH Smith
# 9             PI/000020749                      City Bar & Grill
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9  Restaurant/Cafe/Canteen               1
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                                London City Airport
# 9                      London City Airport (Airside)
#
#                        AddressLine2 AddressLine3  ...  \
# 0                       Sheppy Kent               ...
# 1  Cherry Garden Street Rotherhithe     Charlton  ...
# 2              South Benfleet Essex               ...
# 3                           Tilbury     Charlton  ...
# 4                     Tilbury Essex               ...
# 5                            London               ...
# 6                            London               ...
# 7                            London               ...
# 8                 Silvertown London               ...
# 9                            London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8  {'longitude': 0.0479655750095844, 'latitude': ...
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188850            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Find the new restaurant "Penang Flavours"

# Search for restaurants within 0.01 degree on either side of its latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

# set search criteria
degree_search = 0.01
results_limit = 5

# First find the new restaurant "Penang Flavours"
penang_ent = db.establishments.find_one({'BusinessName' : 'Penang Flavours'})

# get its latitude and longitude

lat = penang_ent['geocode']['latitude']
lng = penang_ent['geocode']['longitude']

# set up the restaurant query
rest_query = {
    'geocode.latitude': {'$gte': lat - degree_search,  '$lte': lat + degree_search},
    'geocode.longitude': {'$gte': lng - degree_search,  '$lte': lng + degree_search},
    'BusinessTypeID': 1,
    'RatingValue' : 5
}

# set up the query for all entities
ent_query = {
    'geocode.latitude': {'$gte': lat - degree_search,  '$lte': lat + degree_search},
    'geocode.longitude': {'$gte': lng - degree_search,  '$lte': lng + degree_search},
    'RatingValue' : 5
}

# hygiene scores are ranked zero as the best, and the higher the rating, the worse the hygiene
sort = [('scores.Hygiene', 1)]

# execute the search                                                                                               
restaurants = list(establishments.find(rest_query).sort(sort).limit(results_limit))

entities = list(establishments.find(ent_query).sort(sort).limit(results_limit))

# Print the results
print(f"Number of restaurants in results: {len(restaurants)}")
print("=============")
pprint(restaurants)
# Out:
# Number of restaurants in results: 1
# =============
# [{'AddressLine1': 'Lowood Eaglesfield Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Shooters Hill Golf Club(Kitchen)',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4647.055611755536,
#   'FHRSID': 694251,
#   'LocalAuthorityBusinessID': 'PI/000046865',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 3DA',
#   'RatingDate': '2020-09-19T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e39b1'),
#   'geocode': {'latitude': 51.4717379, 'longitude': 0.0739321},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694251',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}]

# %%
# print the entities results

print(f"Number of entities in results: {len(entities)}")
print("=============")
pprint(entities)
# Out:
# Number of entities in results: 5
# =============
# [{'AddressLine1': '32 - 38 Falconwood Parade',
#   'AddressLine2': 'Welling',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Rainbow Pre-School At Community Centre',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4645.825814597736,
#   'FHRSID': 468326,
#   'LocalAuthorityBusinessID': '11/00114/CP',
#   'LocalAuthorityCode': '503',
#   'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#   'LocalAuthorityName': 'Bexley',
#   'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'DA16 2PG',
#   'RatingDate': '2018-12-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e32fd'),
#   'geocode': {'latitude': 51.457218, 'longitude': 0.093051},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/468326',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '40 Falconwood Parade',
#   'AddressLine2': 'Welling',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Wine Tavern',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4645.825814758037,
#   'FHRSID': 1424036,
#   'LocalAuthorityBusinessID': '21/00385/CP',
#   'LocalAuthorityCode': '503',
#   'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#   'LocalAuthorityName': 'Bexley',
#   'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'DA16 2PG',
#   'RatingDate': '2021-11-09T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e32fe'),
#   'geocode': {'latitude': 51.457219, 'longitude': 0.093052},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1424036',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '21-23 Falconwood Parade',
#   'AddressLine2': 'Welling',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'The Co-Operative',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4645.8206619798375,
#   'FHRSID': 709085,
#   'LocalAuthorityBusinessID': '17780/0021/0/000',
#   'LocalAuthorityCode': '503',
#   'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#   'LocalAuthorityName': 'Bexley',
#   'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'DA16 2PQ',
#   'RatingDate': '2021-08-17T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e32f7'),
#   'geocode': {'latitude': 51.457402, 'longitude': 0.093377},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/709085',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '33-47 The Green',
#   'AddressLine2': 'Welling',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Falconwood Childrens Shortbreak Service',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4645.819598493023,
#   'FHRSID': 329101,
#   'LocalAuthorityBusinessID': '03/00111/CP',
#   'LocalAuthorityCode': '503',
#   'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#   'LocalAuthorityName': 'Bexley',
#   'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'DA16 2PA',
#   'RatingDate': '2019-05-21T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e32f3'),
#   'geocode': {'latitude': 51.456456, 'longitude': 0.092456},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329101',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '30 Falconwood Parade',
#   'AddressLine2': 'Welling',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Falconwood Pre-school',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4645.825814597736,
#   'FHRSID': 743611,
#   'LocalAuthorityBusinessID': '15/00063/CP',
#   'LocalAuthorityCode': '503',
#   'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#   'LocalAuthorityName': 'Bexley',
#   'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'DA16 2PG',
#   'RatingDate': '2018-09-28T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e32fc'),
#   'geocode': {'latitude': 51.457218, 'longitude': 0.093051},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/743611',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Convert restaurant result to Pandas DataFrame

near_penang_restaurants_df = pd.DataFrame(restaurants)

print(f"Rows in the near Penang Flavours retaurant DataFrame: {len(near_penang_restaurants_df)}")

near_penang_restaurants_df.head()
# Out:
# Rows in the near Penang Flavours retaurant DataFrame: 1
#                         _id  FHRSID  ChangesByServerID  \
# 0  64964159613d83e2052e39b1  694251                  0
#
#   LocalAuthorityBusinessID                      BusinessName  \
# 0             PI/000046865  Shooters Hill Golf Club(Kitchen)
#
#               BusinessType  BusinessTypeID             AddressLine1  \
# 0  Restaurant/Cafe/Canteen               1  Lowood Eaglesfield Road
#
#   AddressLine2 AddressLine3  ...             LocalAuthorityWebSite  \
# 0                 Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                             geocode RightToReply     Distance  \
# 0  {'longitude': 0.0739321, 'latitude': 51.4717379}               4647.055612
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [1 rows x 28 columns]

# %%
# Convert the entities results to a Pandas DataFrame

near_penang_entities_df = pd.DataFrame(entities)

print(f"Rows in the near Penang Flavours entities DataFrame: {len(near_penang_entities_df)}")

near_penang_entities_df.head()
# Out:
# Rows in the near Penang Flavours entities DataFrame: 5
#                         _id   FHRSID  ChangesByServerID  \
# 0  64964159613d83e2052e32fd   468326                  0
# 1  64964159613d83e2052e32fe  1424036                  0
# 2  64964159613d83e2052e32f7   709085                  0
# 3  64964159613d83e2052e32f3   329101                  0
# 4  64964159613d83e2052e32fc   743611                  0
#
#   LocalAuthorityBusinessID                             BusinessName  \
# 0              11/00114/CP   Rainbow Pre-School At Community Centre
# 1              21/00385/CP                              Wine Tavern
# 2         17780/0021/0/000                         The Co-Operative
# 3              03/00111/CP  Falconwood Childrens Shortbreak Service
# 4              15/00063/CP                    Falconwood Pre-school
#
#                             BusinessType  BusinessTypeID  \
# 0                        Caring Premises               5
# 1                      Retailers - other            4613
# 2  Retailers - supermarkets/hypermarkets            7840
# 3                        Caring Premises               5
# 4                        Caring Premises               5
#
#                 AddressLine1 AddressLine2 AddressLine3  ...  \
# 0  32 - 38 Falconwood Parade      Welling         Kent  ...
# 1       40 Falconwood Parade      Welling         Kent  ...
# 2    21-23 Falconwood Parade      Welling         Kent  ...
# 3            33-47 The Green      Welling         Kent  ...
# 4       30 Falconwood Parade      Welling         Kent  ...
#
#       LocalAuthorityWebSite LocalAuthorityEmailAddress  \
# 0  http://www.bexley.gov.uk  food.safety@bexley.gov.uk
# 1  http://www.bexley.gov.uk  food.safety@bexley.gov.uk
# 2  http://www.bexley.gov.uk  food.safety@bexley.gov.uk
# 3  http://www.bexley.gov.uk  food.safety@bexley.gov.uk
# 4  http://www.bexley.gov.uk  food.safety@bexley.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                           geocode RightToReply     Distance  \
# 0  {'longitude': 0.093051, 'latitude': 51.457218}               4645.825815
# 1  {'longitude': 0.093052, 'latitude': 51.457219}               4645.825815
# 2  {'longitude': 0.093377, 'latitude': 51.457402}               4645.820662
# 3  {'longitude': 0.092456, 'latitude': 51.456456}               4645.819598
# 4  {'longitude': 0.093051, 'latitude': 51.457218}               4645.825815
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# The location given for Penang Flavours was not a good choice for a restaurant, near three nursing homes and two preschools.
# I therefore also used an address for what was recommended as one of the top 15 restaurants in Greenwich, in an area of other restaurants.  It is new and unsung and serves Turkish food, which seemed likesomething a customer looking for Halal food might like. I then got the latitude and longitude for that address from https://www.latlong.net/place/blackheath-london-uk-32669.html

# %%
# Search for restaurants within 0.01 degree on either side of its latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

# Set latitude and longitude

rev_lat = 51.465691
rev_lng = 0.005687

# set up the revised restaurant query
rest_query = {
    'geocode.latitude': {'$gte': rev_lat - degree_search,  '$lte': rev_lat + degree_search},
    'geocode.longitude': {'$gte': rev_lng - degree_search,  '$lte': rev_lng + degree_search},
    'BusinessTypeID': 1,
    'RatingValue' : 5
}

# set up the revised query for all entities
ent_query = {
    'geocode.latitude': {'$gte': rev_lat - degree_search,  '$lte': rev_lat + degree_search},
    'geocode.longitude': {'$gte': rev_lng - degree_search,  '$lte': rev_lng + degree_search},
    'RatingValue' : 5
}

# hygiene scores are ranked zero as the best, and the higher the rating, the worse the hygiene
sort = [('scores.Hygiene', 1)]

# execute the search                                                                                               
rev_restaurants = list(establishments.find(rest_query).sort(sort).limit(results_limit))

rev_entities = list(establishments.find(ent_query).sort(sort).limit(results_limit))

# %% [markdown]
# With this revised location, there are many restaurant choices and the other nearby businesses are
# also food-related and much more attractive to foot traffic.

# %%
# Print the restuarant results
print(f"Number of restaurants in results: {len(rev_restaurants)}")
print("=============")
pprint(rev_restaurants)
# Out:
# Number of restaurants in results: 5
# =============
# [{'AddressLine1': '129 Lee Road',
#   'AddressLine2': '',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': "Sapori D'Italia",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.833503681801,
#   'FHRSID': 1111355,
#   'LocalAuthorityBusinessID': '12569',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE3 9DS',
#   'RatingDate': '2021-07-06T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e4173'),
#   'geocode': {'latitude': 51.4577251, 'longitude': 0.0111777},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1111355',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '141 Lee Road',
#   'AddressLine2': '',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Euro Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.8050913047355,
#   'FHRSID': 695267,
#   'LocalAuthorityBusinessID': 'PI/000180650',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE3 9DJ',
#   'RatingDate': '2020-03-07T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e415f'),
#   'geocode': {'latitude': 51.4572434, 'longitude': 0.0114732},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695267',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '5 Lee Road',
#   'AddressLine2': '',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Copper and Ink',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4649.1485185425645,
#   'FHRSID': 1109806,
#   'LocalAuthorityBusinessID': '12508',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE3 9RQ',
#   'RatingDate': '2022-02-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e42b8'),
#   'geocode': {'latitude': 51.464793, 'longitude': 0.0096311},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1109806',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '151 - 157 Lee Road',
#   'AddressLine2': '',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Ristorante Carola',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.783089716947,
#   'FHRSID': 695265,
#   'LocalAuthorityBusinessID': 'PI/000180626',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE3 9DJ',
#   'RatingDate': '2022-06-17T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e414d'),
#   'geocode': {'latitude': 51.456915, 'longitude': 0.0117467},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695265',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '428 Lee High Road',
#   'AddressLine2': 'London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': 'Sims Grill Bar & Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.805809659862,
#   'FHRSID': 256469,
#   'LocalAuthorityBusinessID': 'PI/000091799',
#   'LocalAuthorityCode': '523',
#   'LocalAuthorityEmailAddress': 'david.edwards@lewisham.gov.uk',
#   'LocalAuthorityName': 'Lewisham',
#   'LocalAuthorityWebSite': 'http://www.lewisham.gov.uk/myservices/business/food-safety/Pages/default.aspx',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE12 8RW',
#   'RatingDate': '2019-01-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e416e'),
#   'geocode': {'latitude': 51.456457, 'longitude': 0.010666},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/256469',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Print the entities results
print(f"Number of entities in results: {len(rev_restaurants)}")
print("=============")

print("Nearby businesst types:\n")
for ent in rev_entities:
    print (ent['BusinessType'])
    
print("=============")        
pprint(rev_entities)
# Out:
# Number of entities in results: 5
# =============
# Nearby businesst types:
#
# Takeaway/sandwich shop
# Restaurant/Cafe/Canteen
# Restaurant/Cafe/Canteen
# Restaurant/Cafe/Canteen
# Retailers - supermarkets/hypermarkets
# =============
# [{'AddressLine1': '14 Burnt Ash Road',
#   'AddressLine2': 'London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': 'Sushi Gourmet',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4648.778226550699,
#   'FHRSID': 1434256,
#   'LocalAuthorityBusinessID': 'PI/000304175',
#   'LocalAuthorityCode': '523',
#   'LocalAuthorityEmailAddress': 'david.edwards@lewisham.gov.uk',
#   'LocalAuthorityName': 'Lewisham',
#   'LocalAuthorityWebSite': 'http://www.lewisham.gov.uk/myservices/business/food-safety/Pages/default.aspx',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE12 8PZ',
#   'RatingDate': '2022-02-02T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e4141'),
#   'geocode': {'latitude': 51.45633, 'longitude': 0.011294},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1434256',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '151 - 157 Lee Road',
#   'AddressLine2': '',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Ristorante Carola',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.783089716947,
#   'FHRSID': 695265,
#   'LocalAuthorityBusinessID': 'PI/000180626',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE3 9DJ',
#   'RatingDate': '2022-06-17T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e414d'),
#   'geocode': {'latitude': 51.456915, 'longitude': 0.0117467},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695265',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '428 Lee High Road',
#   'AddressLine2': 'London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': 'Sims Grill Bar & Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.805809659862,
#   'FHRSID': 256469,
#   'LocalAuthorityBusinessID': 'PI/000091799',
#   'LocalAuthorityCode': '523',
#   'LocalAuthorityEmailAddress': 'david.edwards@lewisham.gov.uk',
#   'LocalAuthorityName': 'Lewisham',
#   'LocalAuthorityWebSite': 'http://www.lewisham.gov.uk/myservices/business/food-safety/Pages/default.aspx',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE12 8RW',
#   'RatingDate': '2019-01-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e416e'),
#   'geocode': {'latitude': 51.456457, 'longitude': 0.010666},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/256469',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '141 Lee Road',
#   'AddressLine2': '',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Euro Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4648.8050913047355,
#   'FHRSID': 695267,
#   'LocalAuthorityBusinessID': 'PI/000180650',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE3 9DJ',
#   'RatingDate': '2020-03-07T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e415f'),
#   'geocode': {'latitude': 51.4572434, 'longitude': 0.0114732},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695267',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '14 Burnt Ash Road',
#   'AddressLine2': 'London',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': "Sainsbury's",
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4648.778226550699,
#   'FHRSID': 256068,
#   'LocalAuthorityBusinessID': 'PI/000028338',
#   'LocalAuthorityCode': '523',
#   'LocalAuthorityEmailAddress': 'david.edwards@lewisham.gov.uk',
#   'LocalAuthorityName': 'Lewisham',
#   'LocalAuthorityWebSite': 'http://www.lewisham.gov.uk/myservices/business/food-safety/Pages/default.aspx',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE12 8PZ',
#   'RatingDate': '2018-03-12T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64964159613d83e2052e4143'),
#   'geocode': {'latitude': 51.45633, 'longitude': 0.011294},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/256068',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result
# Print the first 10 results


# set up the pipeline for restaurants and for entities 

match_query = {'$match': {'$and': [{'scores.Hygiene': 0}, 
                                   {'BusinessTypeID': 1}]}}

ent_match_query = {'$match': {'$and': [{'scores.Hygiene': 0}]}}


group_query = {'$group': {'_id': '$LocalAuthorityName', 
                          'count': {'$sum': 1}}}


# hygiene scores are ranked zero as the best, and the higher the rating, the worse the hygiene
          
sort_values = {'$sort': { 'count': -1, '_id': 1 }}

# assemble the restaurant pipeline
rest_pipeline = [match_query, group_query, sort_values]

# assemble the pipeline for all entities
ent_pipeline = [ent_match_query, group_query, sort_values]

# %%
# Run the pipelines through the aggregate method and save the results to a variable

auth_restaurants = list(establishments.aggregate(rest_pipeline))

auth_entities = list(establishments.aggregate(ent_pipeline))

# %% [markdown]
# One might expect that if a local authority has a large number of very clean restaurants, the levels of cleanliness for  other types of establishments would be relatively similar.  That appears not to be the case.  A local authoriy can have top levels of cleanliness in restaurants and not in other entities, and vice versa.
#
# Also note that the levels of cleanliness in the large capital city are at the bottom of the list for all entities and for restaurants specifically.   Given the numbers of tourists, students, members of parliament, and heads of states who visit London, one might have expected a very different result.

# %%
# Print the restaurant results

print(f"Number of Local Authorities in restaurant results: {len(auth_restaurants)}")

print("=============")
print("Top Ten")

pprint(auth_restaurants[0:10])
# Out:
# Number of Local Authorities in restaurant results: 51
# =============
# Top Ten
# [{'_id': 'Thanet', 'count': 358},
#  {'_id': 'Greenwich', 'count': 212},
#  {'_id': 'Chelmsford', 'count': 201},
#  {'_id': 'Maidstone', 'count': 190},
#  {'_id': 'Swale', 'count': 184},
#  {'_id': 'Southend-On-Sea', 'count': 151},
#  {'_id': 'Tunbridge Wells', 'count': 148},
#  {'_id': 'Newham', 'count': 145},
#  {'_id': 'Hastings', 'count': 136},
#  {'_id': 'Colchester', 'count': 128}]

# %%
# Convert the restaurant results to a Pandas DataFrame

auth_restaurants_df = pd.DataFrame(auth_restaurants)

# Display the number of rows in the DataFrame

print(f"There are {len(auth_restaurants_df)} rows in the Local Authorities Restaurants DataFFrame.")

# Display the first 10 rows of the DataFrame

auth_restaurants_df.head(10)
# Out:
# There are 51 rows in the Local Authorities Restaurants DataFFrame.
#                _id  count
# 0           Thanet    358
# 1        Greenwich    212
# 2       Chelmsford    201
# 3        Maidstone    190
# 4            Swale    184
# 5  Southend-On-Sea    151
# 6  Tunbridge Wells    148
# 7           Newham    145
# 8         Hastings    136
# 9       Colchester    128

# %%
# Print the entities results
# The cleanest entity counts are notably different than the cleanest restaurant counts

print(f"Number of Local Authorities in entities results: {len(auth_entities)}")

print("=============")
print("Top Ten")

pprint(auth_entities[0:10])
# Out:
# Number of Local Authorities in entities results: 55
# =============
# Top Ten
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the entities result to a Pandas DataFrame

auth_entities_df = pd.DataFrame(auth_entities)

# Display the number of rows in the DataFrame

print(f"There are {len(auth_entities_df)} rows in the Local Authorities entities DataFrame.")

# Display the first 10 rows of the DataFrame

auth_entities_df.head(10)
# Out:
# There are 55 rows in the Local Authorities entities DataFrame.
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
